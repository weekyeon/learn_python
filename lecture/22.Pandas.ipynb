# %% [markdown]
# # Pandas(Python Data Anlysis Library)
#
# * Pandas는 파이썬에서 사용하는 데이터 분석 라이브러리
# * 행과 열로 이루어진 데이터 객체를 다룰 수 있음
# * 보다 안정적으로 대용량 데이터 처리 시 유용하게 쓰이는 도구
# * Pandas에서는 기본적으로 정의 되어있는 1차원 배열인 **Series**와 2차원 배열인 **DataFrame** 사용
# * 이 자료 구조들은 빅데이터 분석에 있어 높은 수준의 성능을 보여줌
#
# # Reference
# * Pandas DOC : http://pandas.pydata.org/pandas-docs/stable/index.html
# * 자료구조 : http://pandas.pydata.org/pandas-docs/stable/dsintro.html

# %%
# 데이터 분석 주요 라이브러리

# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 한글처리
# from matplotlib import rc, font_manager
# font_name = font_manager.FontProperties(fname="c:/windows/fonts/NanumGothicCoding.ttf").get_name()
# rc('font', family=font_name)

# minus 처리
# rc('axes', unicode_minus=False)

# %%
# pd.show_versions() # full package version
# pd.__version__ # pd version

# %% [markdown]
# ## Series

# %%
# 1. Series 자료 생성 1 - 기본적인 생성법
# 인덱스와 값을 가지는 1차원 배열
# 값들의 리스트를 전달해서 생성함
# 인덱스는 자동적으로 기본적으로 정의되는 정수 인덱스 사용
# 단, 인덱스 정의하지 않으면 0부터 순차적으로 부여됨

# %%
ser = pd.Series([1, 2, 4, np.nan, 6, 8])
print(ser)
print(type(ser))
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# <class 'pandas.core.series.Series'>

# %%
# 2. Series 자료 생성 2 - 인덱스 부여하여 생성하기
# 기본 숫자 인덱스와 문자 인덱스

ser2 = pd.Series([3, 6, 9, 12], index=["2017", "2018", "2019", "2020"])
print(ser2)
# Out:
# 2017     3
# 2018     6
# 2019     9
# 2020    12
# dtype: int64

# %%
ser2.plot()
ser2.plot(kind="bar")
plt.show()

# %%
# Series 자료 생성 3 - key와 인덱스정의
# dictionary 자료형으로 키=인덱스, 값=요소

emp = {"a":500, "b":1000, "c":200, "d":2000}
print(type(emp))

ser3 = pd.Series(emp)
print(ser3)
ser3.plot()
plt.show()
# Out:
# <class 'dict'>
# a     500
# b    1000
# c     200
# d    2000
# dtype: int64

# %%
plt.title("show! X - TICK location") # X축의 TICK 위치 표시하기
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# show() 명령은 시각화 명령을 실제도 차트로 렌더링하고
# 마우스의 동작을 기다리라는 명령이다.
# jupyter notebook에서는 셀 단위로
# 플롯명령을 자동 랜더링해주기 때문에 show 명령은 필요없지만
# 일반적인 Python 인터프리터로 프로그램을 실행하는 경우를 대비해
# 항상 마지막에 실행되도록 작성해주어야 함

# %%
# 스타일 지정(fmt 옵션)
# 스타일 문자열은 색상, 마커, 선종류 순서로 지정
# 만약 이 중에 일부 값 생략 시 기본 값 적용됨

plt.title("rs-- :")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], "rs--")
plt.show()

plt.title("bs- : ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], "bs-")
plt.show()

# %%
plt.title("setting style in graph")
# lw == length width
# ms == marker size
# mec == marker outline
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b", lw=5, ls="--", marker="o", ms=15, mec='g', mew=5, mfc="r")

# 그리드
plt.grid(True)

# 그래프 범위 설정
plt.xlim(0,50)
plt.ylim(-10, 30)


plt.show()

# %% [markdown]
# # 그래프 범위지정
#
# * 그래프를 보면 몇몇 점들을 그래프 범위 경계선에 있어 잘 보이지 않는 경우가 있음
# * 이때, 그래프의 범위를 수동으로 지정할 경우 **xlim(), ylim()** 함수 사용
# * 위 명령은 그래프 범위가 되는 x축, y축의 최솟값과 최댓값을 지정함

# %%
# x,y 틱라벨 설정하기

X = np.linspace()

# %% [markdown]
# # 틱(Tick) 설정
#
# * 그래프에서 축상의 위치표시 지점을 tick이라고 함
# * 이 틱에 쓰여진 숫자 혹은 글자를 틱라벨(Tick Label)이라고 함
# * 틱의 위치나 틱라벨은 Matplotlib에서 자동으로 정해주지만,
# * 수동으로 설정하고자 할 경우에는 **xticks, yticks** 함수 사용
